# %%
#loading the modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the dataset
df=pd.read_csv(r'C:\Users\Admin\Desktop\Datasets\Epileptic Seizure Recognition.csv')
df
# Out:
#           Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  \
# 0      X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17
# 1      X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164
# 2         X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57
# 3       X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82
# 4       X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...
# 11495  X22.V1.114  -22  -22  -23  -26  -36  -42  -45  -42  -45  ...    15
# 11496  X19.V1.354  -47  -11   28   77  141  211  246  240  193  ...   -65
# 11497    X8.V1.28   14    6  -13  -16   10   26   27   -9    4  ...   -65
# 11498  X10.V1.932  -40  -25   -9  -12   -2   12    7   19   22  ...   121
# 11499  X16.V1.210   29   41   57   72   74   62   54   43   31  ...   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# ...

# %%
#info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
#checking for null values
df.isnull().sum()
# Out:
# Unnamed    0
# X1         0
# X2         0
# X3         0
# X4         0
#           ..
# X175       0
# X176       0
# X177       0
# X178       0
# y          0
# Length: 180, dtype: int64

# %%
#data types value counts
df.dtypes.value_counts()
# Out:
# int64     179
# object      1
# Name: count, dtype: int64

# %%
#columns in the dataset
df.columns
# Out:
# Index(['Unnamed', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        ...
#        'X170', 'X171', 'X172', 'X173', 'X174', 'X175', 'X176', 'X177', 'X178',
#        'y'],
#       dtype='object', length=180)

# %%
#summary statistics for the dataframe
df.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %% [markdown]
# Data Preparation

# %%
df=df.drop('Unnamed',axis=1)

# %%
x=df.drop('y',axis=1)
x
# Out:
#         X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X169  X170  \
# 0      135  190  229  223  192  125   55   -9  -33  -38  ...     8   -17
# 1      386  382  356  331  320  315  307  272  244  232  ...   168   164
# 2      -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    29    57
# 3     -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -80   -82
# 4       -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...    10     4
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 11495  -22  -22  -23  -26  -36  -42  -45  -42  -45  -49  ...    20    15
# 11496  -47  -11   28   77  141  211  246  240  193  136  ...   -94   -65
# 11497   14    6  -13  -16   10   26   27   -9    4   14  ...   -42   -65
# 11498  -40  -25   -9  -12   -2   12    7   19   22   29  ...   114   121
# 11499   29   41   57   72   74   62   54   43   31   23  ...   -94   -59
#
#        X171  X172  X173  X174  X175  X176  X177  X178
# ...

# %%
y=df['y']
y
# Out:
# 0        4
# 1        1
# 2        5
# 3        5
# 4        5
#         ..
# 11495    2
# 11496    1
# 11497    5
# 11498    3
# 11499    4
# Name: y, Length: 11500, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_test.shape)
print(y_train.shape)
# Out:
# (9200, 178)
# (2300, 178)
# (2300,)
# (9200,)

# %%
#scaling the data
from  sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %% [markdown]
# Model Building

# %%
 #model selection using logistic regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
#model training
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#fitting the data in the model
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([4, 1, 3, ..., 4, 4, 1], dtype=int64)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.24739130434782608
#               precision    recall  f1-score   support
#
#            1       0.32      0.39      0.35       465
#            2       0.23      0.19      0.21       459
#            3       0.20      0.13      0.16       450
#            4       0.23      0.32      0.27       457
#            5       0.22      0.21      0.22       469
#
#     accuracy                           0.25      2300
#    macro avg       0.24      0.25      0.24      2300
# weighted avg       0.24      0.25      0.24      2300
#
# [[180  60  65  80  80]
#  [ 89  87  51 126 106]
#  [ 73  74  59 151  93]
#  [112  68  69 145  63]
#  [102  88  51 130  98]]

# %% [markdown]
# ##Interpretation
# Dataset Overview:
# The dataset used consists of five distinct classes representing different states of brain activity:
#
# Class 1: Normal brain activity.
# Class 2: Pre-seizure (preictal) state.
# Class 3: Seizure (ictal) state.
# Class 4: Post-seizure (postictal) state.
# Class 5: Other abnormal states of brain activity.
# Model Performance - Logistic Regression:
# The logistic regression model achieved an overall accuracy of 24.7%, meaning it correctly predicted the EEG signal state in about 25% of the cases. Here are the key performance metrics:
#
# ###Accuracy: 0.247
#
# The overall accuracy indicates that the model is correctly classifying roughly 1 in 4 instances. This is relatively low and signals the need for improvement in the model’s ability to distinguish between the five different classes of brain activity.
#
# ##Precision: Measures the proportion of true positive predictions for each class.
#
# Class 1 (normal brain activity) has a precision of 0.32, meaning when the model predicts normal activity, it is correct 32% of the time.
# Classes 2, 3, 4, and 5 show lower precision values (ranging from 0.20 to 0.23), indicating that the model struggles to distinguish these brain activity states accurately.
#
# ###Recall: Reflects the ability of the model to capture actual positive cases.
#
# Class 1 has a recall of 0.39, meaning the model successfully identifies normal brain activity 39% of the time.
# The recall for Class 4 (postictal state) is 0.32, indicating moderate success in identifying this state, but Classes 2 and 3 (preictal and seizure states) have lower recall values of 0.19 and 0.13, respectively, suggesting a significant challenge in recognizing these critical states.
#
# ###F1-Score: A balance between precision and recall.
#
# Class 1 has the highest F1-score of 0.35, but other classes such as Class 2, Class 3, and Class 5 have F1-scores below 0.22, reflecting the overall difficulty in correctly classifying seizure-related activities.
#
# ###Confusion Matrix:
# The confusion matrix shows the number of correct and incorrect predictions made by the model for each class. It indicates how well the model differentiates between states:
#
# For Class 1 (Normal Brain Activity), 180 instances were correctly classified, but the remaining 285 were misclassified into other categories (e.g., 80 into Class 4).
# For Class 3 (Seizure State), only 59 out of 450 instances were correctly classified, with 151 misclassified as Class 4, indicating a major issue in distinguishing seizure states from post-seizure states.

# %%
from sklearn.svm import SVC
svm=SVC()
svm.fit(x_train,y_train)
y_pred=svm.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.5617391304347826
#               precision    recall  f1-score   support
#
#            1       0.96      0.95      0.95       465
#            2       0.48      0.21      0.29       459
#            3       0.45      0.25      0.32       450
#            4       0.82      0.47      0.60       457
#            5       0.38      0.90      0.53       469
#
#     accuracy                           0.56      2300
#    macro avg       0.62      0.56      0.54      2300
# weighted avg       0.62      0.56      0.54      2300
#
# [[441  15   4   4   1]
#  [ 19  97  84  12 247]
#  [  0  55 114  12 269]
#  [  0  28  35 216 178]
#  [  0   8  18  19 424]]

# %% [markdown]
# #Interpretation
# The Support Vector Classifier (SVC) model achieved an overall accuracy of 56.2%, meaning the model correctly classified the EEG signal in 56% of cases. This performance is a moderate improvement from logistic regression but still requires enhancements, especially for certain critical classes.
#
# ###Accuracy: 0.561
# This overall accuracy indicates that the model is correctly predicting slightly more than half of the instances. While better than logistic regression, it's still far from ideal for clinical applications where reliability is paramount.
#
# ###Classification Metrics:
# Precision: Precision measures how often the model’s positive predictions were correct.
#
# Class 1 (normal brain activity) achieved a precision of 0.96, meaning when the model predicts this class, it's correct 96% of the time.
# Class 5 (other abnormal states) has the lowest precision of 0.38, showing that the model often incorrectly predicts this class.
#
# ###Recall: Recall measures how many of the actual cases were correctly predicted.
#
# Class 1 has a recall of 0.95, meaning it correctly identifies normal brain activity 95% of the time.
# Class 5 has the highest recall of 0.90, indicating that when this class appears, the model catches it 90% of the time, but it suffers from lower precision (as seen above).
# Class 2 and Class 3, which represent seizure-related activity, have very low recall values of 0.21 and 0.25, respectively. This suggests the model is struggling significantly to identify these seizure-related states, which is a key concern.
#
# ###F1-Score: The F1-score balances precision and recall.
#
# Class 1 has a high F1-score of 0.95, showing consistent and reliable predictions for normal brain activity.
# Class 4 (post-seizure) and Class 5 (abnormal states) have F1-scores of 0.60 and 0.53, reflecting moderate performance in these areas.
# Classes 2 and 3 have F1-scores below 0.32, further emphasizing the difficulty the model faces in detecting seizure and pre-seizure states.
#
# ###Confusion Matrix:
# The confusion matrix reveals how the model predicts and misclassifies various classes:
#
# Class 1 (Normal Brain Activity): The model is highly successful here, correctly predicting 441 out of 465 cases, with only 24 misclassified.
# Class 5 (Other Abnormal States): 424 out of 469 instances were correctly identified, but 45 cases were misclassified into other categories.
# Class 2 (Pre-seizure) and Class 3 (Seizure): There is significant misclassification in these critical states, as Class 2 had 247 instances misclassified as Class 5, and Class 3 had 269 misclassified as Class 5. This suggests the model confuses seizure-related states with other abnormal brain activity, posing risks in detecting actual seizures.

# %%
#model building using random forest
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.6969565217391305
#               precision    recall  f1-score   support
#
#            1       0.95      0.96      0.96       465
#            2       0.63      0.56      0.59       459
#            3       0.57      0.55      0.56       450
#            4       0.75      0.74      0.75       457
#            5       0.58      0.67      0.62       469
#
#     accuracy                           0.70      2300
#    macro avg       0.70      0.70      0.70      2300
# weighted avg       0.70      0.70      0.70      2300
#
# [[447   6   3   8   1]
#  [ 18 255 117  15  54]
#  [  3 112 249  17  69]
#  [  1   6   8 338 104]
#  [  0  24  60  71 314]]

# %% [markdown]
# #Interpretation
# The Random Forest model achieved an overall accuracy of 69.6%, meaning it correctly classified nearly 70% of EEG signals across the five categories. This indicates a significant improvement over the simpler models like logistic regression and support vector classifier, and suggests the model is capable of handling the complex task of seizure recognition reasonably well.
#
# ###Accuracy: 0.696
# This accuracy suggests that the model is reliable for predicting most of the classes. However, there are still areas for improvement, especially in detecting seizure-related states, which are critical for the intended application.
#
# ###Classification Metrics:
# Precision: Precision refers to how often the model's positive predictions were correct.
#
# Class 1 (normal brain activity) has a very high precision of 0.95, meaning when the model predicts normal brain activity, it is correct 95% of the time.
# Class 5 (other abnormal states) has a moderate precision of 0.60, reflecting some degree of misclassification with other categories.
#
# ###Recall: Recall indicates how many actual cases were correctly identified by the model.
#
# Class 1 has a recall of 0.95, showing the model is highly successful at identifying normal brain activity.
# Class 5 has a relatively high recall of 0.68, indicating the model correctly identifies most of the abnormal brain states but still confuses a few cases with other categories.
# Class 2 and Class 3, which represent seizure-related activities, have lower recall values of 0.55 and 0.57, respectively. This suggests the model is better at detecting these seizure-related activities compared to earlier models but still misses several instances.
#
# ###F1-Score: The F1-score is a balanced measure of precision and recall.
#
# Class 1 (normal activity) has a strong F1-score of 0.95, showing consistent and reliable predictions for this class.
# Class 4 (post-seizure states) and Class 5 (other abnormal states) have F1-scores of 0.74 and 0.64, respectively, indicating moderate performance.
# Classes 2 and 3 (seizure-related activity) have F1-scores of 0.57, showing the model's performance is decent but not as reliable for detecting seizure activity.
#
# ###Confusion Matrix:
# The confusion matrix reveals how the model classifies the EEG signals:
#
# Class 1 (Normal Brain Activity): The model performs exceptionally well in predicting this class, with 444 out of 465 instances correctly identified. There are only minor misclassifications to other classes.
# Class 2 (Pre-seizure Activity): Out of 459 instances, 253 were correctly identified, but 121 were misclassified into Class 3 (seizure activity). This confusion between seizure-related classes is a concern.
# Class 3 (Seizure Activity): Out of 450 instances, 255 were correctly classified, but 118 were misclassified into Class 2 and 60 into Class 5. The model has difficulty differentiating between seizure and other abnormal states.
# Class 4 (Post-seizure State): 329 out of 457 instances were correctly classified, with most misclassifications occurring between Class 4 and Class 5, likely due to similarities in the post-seizure and abnormal brain states.
# Class 5 (Other Abnormal States): The model correctly identified 319 out of 469 instances, with 58 misclassified as Class 3 and 57 as Class 4.

# %%
#Assigning the confusion matrix to cm
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=["Class 1", "Class 2", "Class 3", "Class 4", "Class 5"],
            yticklabels=["Class 1", "Class 2", "Class 3", "Class 4", "Class 5"])
plt.title('Confusion Matrix for Logistic Regression')
plt.ylabel('Actual Labels')
plt.xlabel('Predicted Labels')
plt.show()
